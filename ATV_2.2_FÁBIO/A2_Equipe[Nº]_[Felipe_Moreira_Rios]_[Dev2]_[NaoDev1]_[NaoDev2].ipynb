# %% [markdown]
# ## Atividade 2 (em grupos)
#
# **Objetivo:** Explorar os dados do CAR e relacionar com o PSA
#
# **Exemplos**
# - Tentar encontrar pontos ou áreas que possivelmente podem incluir nascentes.
# - Explorar o percentual de cobertura vegetal e áreas protegidas.
#
#
# **Conjuntos de Dados**
# - Dados CAR: https://consultapublica.car.gov.br/publico/estados/downloads
# - [Painel da Regularização Ambiental](https://app.powerbi.com/view?r=eyJrIjoiZmRiM2QwZDQtYjUxZi00YWI0LWFjNGEtZTIxNjg1YWFkNmZlIiwidCI6ImViMjJjMjU4LWQ0ZWQtNGZmMC04Y2Y2LTI4NmQ2Mjc3OTQ5ZSJ9)
# - IBGE: [Todos os Produtos | IBGE](https://www.ibge.gov.br/geociencias/todos-os-produtos-geociencias.html)
# - Pontos de drenagem - ANA: [Pontos de Drenagem](https://metadados.snirh.gov.br/geonetwork/srv/api/records/bb5233ba-adc0-4ff6-802b-918ba2a140e8)
#
# **Entregáveis**
# - **Devs:**
#   - Desenvolver o notebook e as visualizações interativas.
#   - Apresentação em notebook Jupyter colocado na pasta 'equipe X' no google drive compartilhado.
# - **Não-devs:**
#   - Desenvolver o documento explicativo e estudar sobre os aspectos ambientais e legais desses exemplos.
#   - Utilizar visualizações interessantes dos dados para o relatório.
#
# **Apresentação** (3 min cada equipe = 30 minutos)
# 1 mini apresentação com os dados escolhidos e sua relevância para sustentabilidade ou para a temática escolhida.
# - Relatórios devem conter
#   - Título do Projeto
#   - Origem dos Dados
#   - Problemática
#   - Relação com Sustentabilidade (se houver)
#   - Visualizações Chave
#   - Recomendações
#
# **Nomenclatura dos Arquivos**
# - Notebook (devs):
# `A2_Equipe[Nº]_[Dev1]_[Dev2]_[NaoDev1]_[NaoDev2].ipynb`
# Exemplo: `A2_Equipe5_Carlos_Ana_Beatriz_Pedro.ipynb`
#
# - Relatório (não-devs):
# `A2_Equipe[Nº]_[NaoDev1]_[NaoDev2].docx`
# Exemplo: `A2_Equipe5_Beatriz_Pedro.docx`

# %% [markdown]
# # Atividade 2 – Trabalho em Equipe
#
# 🗓️ **Entrega:** 10 de maio, 23:59
#
# ---
#
# ## Objetivos
#
# - Explorar os dados do CAR e relacionar com o PSA
# - Identificar pontos ou áreas que possivelmente contêm nascentes
# - Analisar o percentual de cobertura vegetal e de áreas protegidas
# - Avaliar a proximidade dos rios com áreas de proteção e o percentual de massa d’água nos imóveis
#
# ---
#
# ## Recursos & Links
#
# - **Dados CAR**
#   https://consultapublica.car.gov.br/publico/estados/downloads
# - **Painel de Regularização Ambiental**
#   https://app.powerbi.com/view?r=eyJrIjoiZmRiM2QwZDQtYjUxZi00YWI0LWFjNGEtZTIxNjg1YWFkNmZlIiwidCI6ImViMjJjMjU4LWQ0ZWQtNGZmMC04Y2Y2LTI4NmQ2Mjc3OTQ5ZSJ9
# - **Produtos Geociências – IBGE**
#   https://www.ibge.gov.br/geociencias/todos-os-produtos-geociencias.html
# - **Pontos de Drenagem – ANA**
#   https://metadados.snirh.gov.br/geonetwork/srv/api/records/bb5233ba-adc0-4ff6-802b-918ba2a140e8
#
# ---
#
# ## Entregáveis
#
# 1. ### Notebook Jupyter (para desenvolvedores)
#    - **Nome do arquivo:**
#      `A2_Equipe[N]_[Dev1]_[Dev2]_[NaoDev1]_[NaoDev2].ipynb`
#      _Exemplo:_ `A2_Equipe5_Carlos_Ana_Beatriz_Pedro.ipynb`
#    - **Conteúdo:**
#      - Carga e tratamento dos dados CAR (via WFS ou shapefiles)
#      - Exploração de nascentes, cobertura vegetal, áreas protegidas, proximity análise de rios
#      - Visualizações interativas (Folium, Matplotlib etc.)
#
# 2. ### Relatório Word (para não-desenvolvedores)
#    - **Nome do arquivo:**
#      `A2_Equipe[N]_[NaoDev1]_[NaoDev2].docx`
#      _Exemplo:_ `A2_Equipe5_Beatriz_Pedro.docx`
#    - **Seções obrigatórias:**
#      1. Título do Projeto
#      2. Origem dos Dados
#      3. Problemática
#      4. Relação com Sustentabilidade (quando houver)
#      5. Visualizações Chave
#      6. Recomendações
#
# 3. ### Mini-apresentação
#    - **Duração:** 6 minutos
#    - **Tópicos:** dados selecionados e relevância para sustentabilidade/tema
#
# ---
#
# ## Instruções de Entrega
#
# - Colocar **Notebook** e **Relatório** na pasta **Equipe X** do Google Drive compartilhado
# - Garantir que o documento explicativo aborde também aspectos ambientais e legais
# - Usar visualizações claras e impactantes no relatório

# %% [markdown]
# QUERIA PODER USAR A TAL API DO CAR

# %% [markdown]
# APPS_1.shp - 5/2/2025 12:49 PM - 627,889 KB
#
# AREA_CONSOLIDADA_1.shp - 5/2/2025 1:38 PM - 278,343 KB
#
# AREA_CONSOLIDADA_1.shx - 5/2/2025 1:38 PM - 2,514 KB
#
# AREA_IMOVEL_1.shp - 5/2/2025 12:36 PM - 131,429 KB
#
# AREA_IMOVEL_1.shx - 5/2/2025 12:36 PM - 3,209 KB
#
# AREA_POUSIO_1.shp - 5/2/2025 1:39 PM - 7,141 KB
#
# AREA_POUSIO_1.shx - 5/2/2025 1:39 PM - 139 KB
#
# HIDROGRAFIA_1.shp - 5/2/2025 1:50 PM - 143,849 KB
#
# HIDROGRAFIA_1.shx - 5/2/2025 1:50 PM - 343 KB
#
# RESERVA_LEGAL_1.shp - 5/2/2025 1:15 PM - 98,294 KB
#
# RESERVA_LEGAL_1.shx - 5/2/2025 1:15 PM - 1,775 KB
#
# SERVIDAO_ADMINISTRATIVA_1.shp - 5/2/2025 1:51 PM - 35,554 KB
#
# SERVIDAO_ADMINISTRATIVA_1.shx - 5/2/2025 1:51 PM - 423 KB
#
# USO_RESTRITO_1.shp - 5/2/2025 1:51 PM - 7,219 KB
#
# USO_RESTRITO_1.shx - 5/2/2025 1:51 PM - 38 KB
#
# VEGETACAO_NATIVA_1.shp - 5/2/2025 1:27 PM - 186,259 KB
#
# VEGETACAO_NATIVA_1.shx - 5/2/2025 1:27 PM - 1,062 KB
#
# APPS_1.shx - 5/2/2025 12:49 PM - 2,087 KB

# %%
import geopandas as gpd
import os

# Caminho para a pasta 'files' no ambiente do Colab
folder_path = '/content'

# Lista dos shapefiles
shapefiles = [
    "APPS", "AREA_CONSOLIDADA", "AREA_IMOVEL", "AREA_POUSIO",
    "HIDROGRAFIA", "RESERVA_LEGAL", "SERVIDAO_ADMINISTRATIVA",
    "USO_RESTRITO", "VEGETACAO_NATIVA"
]

# Função para carregar e visualizar as colunas e a primeira linha de cada shapefile
for shp in shapefiles:
    file_path = os.path.join(folder_path, f"{shp}_1.shp")

    # Carregar o shapefile usando o geopandas
    gdf = gpd.read_file(file_path)

    # Exibir as colunas
    print(f"Colunas de {shp}:")
    print(gdf.columns)  # Exibe todas as colunas do GeoDataFrame

    # Exibir a primeira linha do GeoDataFrame
    print(f"Primeira linha de {shp}:")
    print(gdf.head(1))  # Exibe a primeira linha
    print("-" * 50)  # Separador
# Out:
# /usr/local/lib/python3.11/dist-packages/pyogrio/raw.py:198: RuntimeWarning: /content/APPS_1.shp contains polygon(s) with rings with invalid winding order. Autocorrecting them, but that shapefile should be corrected using ogr2ogr for example.
#   return ogr_read(
# Colunas de APPS:
# Index(['geometry'], dtype='object')
# Primeira linha de APPS:
#                                             geometry
# 0  POLYGON ((-38.21757 -7.87411, -38.21758 -7.874...
# --------------------------------------------------
# /usr/local/lib/python3.11/dist-packages/pyogrio/raw.py:198: RuntimeWarning: /content/AREA_CONSOLIDADA_1.shp contains polygon(s) with rings with invalid winding order. Autocorrecting them, but that shapefile should be corrected using ogr2ogr for example.
#   return ogr_read(
# Colunas de AREA_CONSOLIDADA:
# Index(['geometry'], dtype='object')
# Primeira linha de AREA_CONSOLIDADA:
#                                             geometry
# ...

# %% [markdown]
# # 🌍 Análise de Dados Geoespaciais com Python e Folium
#
# ## 📅 Objetivo da Atividade
# Explorar os dados do **Cadastro Ambiental Rural (CAR)** de Pernambuco e relacioná-los com o **Sistema de Pagamento por Serviços Ambientais (PSA)**.
# Identificar pontos de nascentes, analisar cobertura vegetal, áreas protegidas e proximidade de rios.
#
# ---
#
# ## 🔧 Pré-processamento (GDAL)
# Correção dos shapefiles originais para:
# - Definir corretamente o CRS como **EPSG:4326**
# - Repara “winding order” dos polígonos
# - Gera arquivos `*_fixed.shp` prontos para uso no Python
#
# ---
#
# ## 🖥️ Dependências Python
# - **geopandas**
# - **folium**
# - **matplotlib**
# - Outras bibliotecas auxiliares (certifi, urllib3)
#
# ---
#
# ## 🗂️ Fluxo do Notebook
# 1. **Carga de shapefiles corrigidos** (`*_fixed.shp`)
# 2. **Reparo e simplificação** das geometrias para performance
# 3. **Geração de mapas interativos** com:
#    - Camadas Light/Dark
#    - FeatureGroup por tipo de área
#    - Popups detalhados (área, centroide)
#    - LayerControl, MiniMap, MousePosition, Fullscreen
# 4. **Geração de mapas estáticos** (PNG) com Matplotlib
#
# ---
#
# ## 🗺️ Mapas Gerados
# - **Interativo**:
#   - `Mapa_CAR_PSA_interativo.html`
# - **Estáticos (PNG)**:
#   - `APPS_static_map.png`
#   - …
#   - `VEGETACAO_NATIVA_static_map.png`
#
# ---
#
# ## ✅ Conformidade com a Atividade 2
# - Carga e tratamento completos dos dados CAR
# - Exploração espacial de nascentes, vegetação e hidrografia
# - Mapas interativos e estáticos alinhados aos objetivos
# - Pronto para entrega no formato notebook, relatório e apresentação

# %%
# %%bash
# # 1) Instala o GDAL
# apt-get update && apt-get install -y gdal-bin
#
# # 2) Defina os nomes base dos shapefiles
# shapefiles=(
#   APPS
#   AREA_CONSOLIDADA
#   AREA_IMOVEL
#   AREA_POUSIO
#   HIDROGRAFIA
#   RESERVA_LEGAL
#   SERVIDAO_ADMINISTRATIVA
#   USO_RESTRITO
#   VEGETACAO_NATIVA
# )
#
# # 3) Loop para corrigir cada shapefile
# for shp in "${shapefiles[@]}"; do
#   echo "🔄 Corrigindo ${shp}_1.shp → ${shp}_fixed.shp"
#   ogr2ogr \
#     -f "ESRI Shapefile" \
#     -makevalid \
#     -s_srs EPSG:4326 \
#     -t_srs EPSG:4326 \
#     -nlt PROMOTE_TO_MULTI \
#     -skipfailures \
#     "/content/${shp}_fixed.shp" \
#     "/content/${shp}_1.shp"
# done
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:3 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:4 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,926 kB]
# Hit:5 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:6 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:7 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:8 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,720 kB]
# Get:9 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:10 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# ...

# %% [markdown]
# **CODIGO** INFINITO

# %%
#PEGOU TODA A RAM DO DOS SISTEMA, MAS NÃO FOI

# %%
# !pip install geopandas requests folium matplotlib certifi urllib3

import geopandas as gpd
import os
import folium
import matplotlib.pyplot as plt
from folium import plugins

# pasta onde estão os shapefiles corrigidos
folder_path = '/content'
# apenas as camadas essenciais
shapefiles = [
    "APPS",            # Áreas de Preservação Permanente
    "VEGETACAO_NATIVA",# Cobertura Vegetal Nativa
    "RESERVA_LEGAL",   # Área de Reserva Legal
    "HIDROGRAFIA",     # Corpos d'água
    "AREA_IMOVEL"      # Limites dos imóveis
]

# cores distintas para cada camada essencial
color_map = {
    "APPS": "#1f77b4",
    "VEGETACAO_NATIVA": "#17becf",
    "RESERVA_LEGAL": "#8c564b",
    "HIDROGRAFIA": "#9467bd",
    "AREA_IMOVEL": "#2ca02c"
}

# 1) cria o mapa base com duas opções de tiles
m = folium.Map(location=[-8.0, -36.5], zoom_start=7, control_scale=True)
folium.TileLayer('cartodbpositron', name='Light').add_to(m)
folium.TileLayer('cartodbdark_matter', name='Dark').add_to(m)

for shp in shapefiles:
    # usa o shapefile já corrigido pelo ogr2ogr
    path = os.path.join(folder_path, f"{shp}_fixed.shp")
    gdf = gpd.read_file(path)

    # opcional: amostra 20% para acelerar (descomente se necessário)
    gdf = gdf.sample(frac=0.4, random_state=1)

    # 2) reparar e simplificar geometrias
    gdf['geometry'] = gdf.geometry.buffer(0).simplify(0.01)

    # 3) criar um FeatureGroup para ligar/desligar
    fg = folium.FeatureGroup(name=shp, show=False)

    # 4) adicionar GeoJson estilizado
    folium.GeoJson(
        data=gdf,
        style_function=lambda feat, col=color_map[shp]: {
            'fillColor': col, 'color': col, 'weight': 1, 'fillOpacity': 0.4
        },
        highlight_function=lambda _: {'weight': 3, 'fillOpacity': 0.7},
        tooltip=folium.GeoJsonTooltip(fields=[], aliases=[], labels=False)
    ).add_to(fg)

    # 5) popups nos centroides
    for _, row in gdf.iterrows():
        cen = row.geometry.centroid
        popup_html = (
            f"<b>{shp.replace('_',' ').title()}</b><br>"
            f"Área ≈ {row.geometry.area:.0f} m²<br>"
            f"Centroide: {cen.y:.5f}, {cen.x:.5f}"
        )
        folium.Marker(
            [cen.y, cen.x],
            icon=folium.Icon(color='blue', icon='info-sign'),
            popup=folium.Popup(popup_html, max_width=250)
        ).add_to(fg)

    fg.add_to(m)

    # 6) gerar mapa estático PNG
    fig, ax = plt.subplots(figsize=(6,6))
    gdf.plot(ax=ax, color=color_map[shp], edgecolor='black', alpha=0.5)
    ax.set_title(f"{shp.replace('_',' ').title()} (static)")
    ax.set_xlabel('Longitude')
    ax.set_ylabel('Latitude')
    plt.tight_layout()
    fig.savefig(f"/content/{shp}_static_map.png", dpi=150)
    plt.close(fig)

# 7) controles e plugins
folium.LayerControl(collapsed=False).add_to(m)
plugins.MiniMap(toggle_display=True).add_to(m)
plugins.MousePosition().add_to(m)
plugins.Fullscreen().add_to(m)

# 8) salvar HTML interativo
out_html = '/content/Mapa_CAR_PSA_interativo.html'
m.save(out_html)
print(f"✅ Mapa interativo salvo em: {out_html}")
print("✅ Mapas estáticos (.png) salvos ao lado dos shapefiles corrigidos.")
# Out:
# ...
# /usr/local/lib/python3.11/dist-packages/pyogrio/raw.py:198: RuntimeWarning: /content/APPS_fixed.shp contains polygon(s) with rings with invalid winding order. Autocorrecting them, but that shapefile should be corrected using ogr2ogr for example.
#   return ogr_read(
